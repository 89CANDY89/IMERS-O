# %% [markdown]
# <a href="https://colab.research.google.com/github/89CANDY89/IMERS-O/blob/main/1D_IMERS%C3%83O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRIMEIRO DIA DESAFIO IMERSÃO ALURA**

# %%
import pandas as pd
import matplotlib.pyplot as plt

#IMPORTAR OS DADOS ZIPADOS
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
#Plota as cinco primeiras linhas da base de dados.
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Mostra Rows, Columns
dados.shape
# Out:
# (23814, 877)

# %%
#Mostra todos os dados da colina selecionada
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
#Mostra todos os dados unicos da coluna.
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
#Conseguimos observar que os dados do tempo são horas, nesta base de dados
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
#Na base de dados duas doses, D1 pode ser dose menor que a D2, mais não se pode afirmar isso ainda.
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
#Os dados são alterado em cada teste para não saber qual droga foi usado, assim não tendo um viés na pesquisa
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
#A letra g é a abreviação de gene, e os número são as expressão do gene estudado
#A expressão genetica e quando gene se transforma em 4 RNAs, logo a expressão é de um 1x, caso com estimulo pode gerar mais de 4 RNAs.
#por exemplo se gerar 8 RNAs a expressão vai ser 2x
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
#Mostra a frequencia que aparece a variavel
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
#Mostra a tabela onde o g-0 e maior que 0
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento  é tão desbalanciada?

# %%
#Analisar os valores com_controle
controle = dados.query('tratamento == "com_controle"')
controle
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63     id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ...  0.2131 -0.1419 -0.2422  0.0457
# 23747  id_ff469c482  com_controle     72   D1  ... -0.9630  0.8872 -0.0742 -0.6777
# 23768  id_ff89331ca  com_controle     72   D2  ...  0.9517 -0.8110 -0.1748 -0.3626
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# ...

# %% [markdown]
# Analisando a quantidade de drogas e controle

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# f0d1b8dbc       1
# 5bbc89d67       1
# 263b9a195       1
# ffe357f8f       1
# a1a9a44dd       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# Apresenta apenas uma variavel controle entre as drogas. Portanto, o numero de controle é bem menor em relação aod e drogas

# %% [markdown]
# ###Desafio 02: Plotar as cinco últimas linhas da tabela?

# %%
dados.tail(5)  # .tail retorna as últimas linhas
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 03: Proporção das classe tratamento?

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tempo'].value_counts(normalize = True)
# Out:
# 48    0.346435
# 72    0.327202
# 24    0.326363
# Name: tempo, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# ###Desafio 04: Quantos tipos de drogas foram investigadas?

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 07cca32e8       1
# 0dedfb162       1
# 125db1da8       1
# ed64cad3a       1
# 263b9a195       1
# Name: droga, Length: 3289, dtype: int64

# %%
print(str(len(dados['droga'].value_counts()))+ ' drogas foram utilizadas')
# Out:
# 3289 drogas foram utilizadas

# %%
dados['droga'].nunique() # Nunique devolve o valor total das drogas usada neste caso.
# Out:
# 3289

# %% [markdown]
# ###Desafio 05: Procurar na documentação o método query(pandas)?

# %%
dados.query('g0 > 1')
# Out:
#                  id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 6      id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 16     id_002fb9c19  com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 39     id_0079d45d3  com_droga     24   D1  ... -2.7020 -2.2530 -4.8360 -0.6461
# 48     id_008b48693  com_droga     24   D1  ... -0.2725 -0.1511 -0.4635 -0.1365
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23749  id_ff4fcb445  com_droga     48   D1  ...  1.4160  0.2399 -0.4236  0.7803
# 23776  id_ff9d0a022  com_droga     24   D2  ... -7.5290 -6.3180 -5.7010 -3.5610
# 23791  id_ffd1fd119  com_droga     72   D2  ... -9.9660 -8.6420 -9.9660 -4.6050
# 23802  id_fff3976bd  com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5  com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
#
# ...

# %% [markdown]
# ###Desafio 06: Renomear as colunas tirando o hífen?

# %%
dados.columns = dados.columns.str.replace('-', '')

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 07: Deixar os gráficos bonitões

# %%
dados['tratamento'].value_counts().plot(kind='bar',color=['orange','blue'])

font = {'family':'serif','color':'Black','size':15}
plt.title('Tratamento', fontdict=font)
plt.xlabel('Tipo de tratamento', fontdict=font)
plt.ylabel('Quantidade administrada', fontdict=font)
plt.xticks(rotation=0)
plt.grid(axis='y',color = 'black', linestyle = '--', linewidth = 0.1, b='bool')

# %%
dados['tempo'].value_counts().plot(kind='bar',color=['orange','blue', 'yellow'])

font = {'family':'serif','color':'black','size':15}
plt.title('Tempo', fontdict=font)
plt.xlabel('Tempo da análise (horas)', fontdict=font)
plt.ylabel('Amostras análisadas', fontdict=font)
plt.xticks(rotation=0)
plt.grid(axis='y',color = 'black', linestyle = '--', linewidth = 0.2, b='bool')

# %% [markdown]
# ### Desafio 08: Resumo do que você aprendeu com os dados?

# %% [markdown]
# Usar o google drive com Panda
#
# Linkar o gift hub com google drive.
#
# Plotar e reestrutrar graficos
